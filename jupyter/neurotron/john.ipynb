# %%
# John likes to dance

from neurotron import Cells, Trainer

train = Trainer(cells:=Cells((2,9,8,3),3),plot=True)

# %%
train('Mary likes to sing')
# Out:
# '<Mary likes to sing>'

# %%
cells.run('Mary',...)
# Out:
# ['Mary', '->', 'likes', 'to', 'sing', '']

# %%
train('John likes to dance')
# Out:
# '<John likes to dance>'

# %%
print(cells.run('John likes',...))
print(cells.run('Mary likes',...))
# Out:
# ['John', '->', 'likes', 'to', 'dance', '']
# ['Mary', '->', 'likes', 'to', 'sing', '']

# %%
print(cells.run('John'))
cells.plot()
# Out:
# ['John', '->', 'likes']

# %%
train('Lisa likes to paint')
# Out:
# '<Lisa likes to paint>'

# %%
print(cells.run('John',...))
print(cells.run('Mary',...))
print(cells.run('Lisa',...))
# Out:
# ['John', '->', 'likes', 'to', 'dance', '']
# ['Mary', '->', 'likes', 'to', 'sing', '']
# ['Lisa', '->', 'likes', 'to', 'paint', '']

# %%
train('Andy likes to climb')
# Out:
# '<Andy likes to climb>'

# %%
print(cells.run('John',...))
print(cells.run('Mary',...))
print(cells.run('Lisa',...))
print(cells.run('Andy likes',...))
# Out:
# ['John', '->', 'likes', 'to', 'dance', '']
# ['Mary', '->', 'likes', 'to', 'sing', '']
# ['Lisa', '->', 'likes', 'to', 'paint', '']
# ['Andy', '->', 'likes', 'to', 'climb', '']

# %%
from neurotron import Cells, Trainer

train = Trainer(cells:=Cells((2,9,8,3),3))
train('Andy likes to climb')
cells.run('Andy likes',...)
# Out:
# ['Andy', '->', 'likes', 'to', 'climb', '']
